# %% [markdown]
# Create a lambda function for calculating the square of a number.

# %%
squared = lambda x : x**2 # Defining the Lambda Function assigning variable and sqaure it.

# %%
squared(5)
# Out:
# 25

# %%
print(f"square of number{squared(10)}")
# Out:
# square of number100
