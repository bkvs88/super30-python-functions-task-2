# %% [markdown]
# create function for multiplication

# %%
def mult(a, b): # define a function named mult that takes two parameters a and b
    '''ArithmeticError: This function takes two numbers as input and returns their product.'''
    return a * b #return the product of a and b

# %%
mult(4, 5)
# Out:
# 20
