# %% [markdown]
# Create a function using *args that returns the largest supplied number.

# %%
def largest_number(*numbers:int|float) -> int|float: #defining the function with parameter packing as input of numbers as tuple
    return max(numbers) #returning the max numbers from given tuple

# %%
largest_number(1,2,3,44,46,4645,566.65)
# Out:
# 4645
