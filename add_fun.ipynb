# %% [markdown]
# Create def add(a, b) that returns the addition of two numbers.

# %%
def add(a, b): # define a function named add that takes two parameters a and b
    '''ArithmeticError: This function takes two numbers as input and returns their sum.'''
    return a + b #return the sum of a and b

# %%
add(4,5)
# Out:
# 9
