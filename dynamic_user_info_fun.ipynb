# %% [markdown]
# Create
#
# def create_profile(**kwargs)
#
# that accepts dynamic user information and prints all provided attributes.

# %%
def create_profile(**kwargs): #Defining the function create profile with input as dictionary positional parameters
    for key, value in kwargs.items():
        print(f"{key}: {value}") #Return the user input with dictionary key value pairs.

# %%
create_profile(name="sravan",age=38,location="Singapore",Planet="Earth")
# Out:
# name: sravan
# age: 38
# location: Singapore
# Planet: Earth

# %%
create_profile(name="sravan",age=38,location="Singapore",Planet="Earth",Gender="M")
# Out:
# name: sravan
# age: 38
# location: Singapore
# Planet: Earth
# Gender: M
