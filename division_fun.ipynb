# %% [markdown]
# Create functions for division

# %%
def div(a, b): # define a function named div that takes two parameters a and b
    '''ArithmeticError: This function takes two numbers as input and returns their quotient.'''
    return a / b #return the quotient of a and b

# %%
div(4, 2)
# Out:
# 2.0
