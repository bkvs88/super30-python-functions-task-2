# %% [markdown]
# Create function for substraction

# %%
def sub(a, b): # define a function named sub that takes two parameters a and b
    '''ArithmeticError: This function takes two numbers as input and returns their difference.'''
    return a - b #return the difference of a and b

# %%
sub(4,3)
# Out:
# 1
